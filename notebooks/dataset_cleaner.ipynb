# %%
import pandas as pd
import numpy as np

df = pd.read_csv('../datasets/zomato_data_raw.csv')
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 51717 entries, 0 to 51716
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   url                          51717 non-null  str
#  1   address                      51717 non-null  str
#  2   name                         51717 non-null  str
#  3   online_order                 51717 non-null  str
#  4   book_table                   51717 non-null  str
#  5   rate                         43942 non-null  str
#  6   votes                        51717 non-null  int64
#  7   phone                        50509 non-null  str
#  8   location                     51696 non-null  str
#  9   rest_type                    51490 non-null  str
#  10  dish_liked                   23639 non-null  str
#  11  cuisines                     51672 non-null  str
#  12  approx_cost(for two people)  51371 non-null  str
# ...

# %%
df.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# ...

# %%
clean_df = df[['name', 'online_order', 'book_table', 'rate', 'votes', 'location', 'rest_type', 'cuisines', 'listed_in(type)', 'listed_in(city)']]
clean_df.columns = ['Name', 'Online_Order', 'Book_Table', 'Rating', 'Votes', 'Location', 'Restaurant_Type', 'Cuisines', 'Listed_Type', 'Listed_City']
clean_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 51717 entries, 0 to 51716
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             51717 non-null  str
#  1   Online_Order     51717 non-null  str
#  2   Book_Table       51717 non-null  str
#  3   Rating           43942 non-null  str
#  4   Votes            51717 non-null  int64
#  5   Location         51696 non-null  str
#  6   Restaurant_Type  51490 non-null  str
#  7   Cuisines         51672 non-null  str
#  8   Listed_Type      51717 non-null  str
#  9   Listed_City      51717 non-null  str
# dtypes: int64(1), str(9)
# memory usage: 8.6 MB

# %%
clean_df = clean_df[clean_df['Rating'] != 'NEW']
clean_df = clean_df.dropna(subset=['Rating', 'Location', 'Restaurant_Type', 'Cuisines'])
clean_df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 41574 entries, 0 to 51716
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             41574 non-null  str
#  1   Online_Order     41574 non-null  str
#  2   Book_Table       41574 non-null  str
#  3   Rating           41574 non-null  str
#  4   Votes            41574 non-null  int64
#  5   Location         41574 non-null  str
#  6   Restaurant_Type  41574 non-null  str
#  7   Cuisines         41574 non-null  str
#  8   Listed_Type      41574 non-null  str
#  9   Listed_City      41574 non-null  str
# dtypes: int64(1), str(9)
# memory usage: 7.3 MB

# %%
hyphen_ratings = clean_df['Rating'].str.contains('-', na=False)

clean_df = clean_df[~hyphen_ratings]
clean_df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 41505 entries, 0 to 51716
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             41505 non-null  str
#  1   Online_Order     41505 non-null  str
#  2   Book_Table       41505 non-null  str
#  3   Rating           41505 non-null  str
#  4   Votes            41505 non-null  int64
#  5   Location         41505 non-null  str
#  6   Restaurant_Type  41505 non-null  str
#  7   Cuisines         41505 non-null  str
#  8   Listed_Type      41505 non-null  str
#  9   Listed_City      41505 non-null  str
# dtypes: int64(1), str(9)
# memory usage: 7.3 MB

# %%
clean_df['Online_Order'] = clean_df['Online_Order'].map({
    "Yes": True,
    "No": False
})

clean_df['Book_Table'] = clean_df['Book_Table'].map({
    "Yes": True,
    "No": False
})

clean_df['Rating'] = clean_df['Rating'].str.strip()
clean_df['Rating'] = clean_df['Rating'].str.split('/5').str[0]
clean_df['Rating'] = clean_df['Rating'].str.strip().astype(float)

clean_df
# Out:
#                                                     Name  Online_Order  \
# 0                                                  Jalsa          True
# 1                                         Spice Elephant          True
# 2                                        San Churro Cafe          True
# 3                                  Addhuri Udupi Bhojana         False
# 4                                          Grand Village         False
# ...                                                  ...           ...
# 51709                         The Farm House Bar n Grill         False
# 51711                                            Bhagini         False
# 51712  Best Brews - Four Points by Sheraton Bengaluru...         False
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...         False
# 51716                       The Nest - The Den Bengaluru         False
#
#        Book_Table  Rating  Votes                    Location  \
# ...

# %%
clean_df.to_csv('../datasets/zomato_data_cleaned.csv', index=False)
